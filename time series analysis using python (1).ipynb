# %% [markdown]
# # Time Series Analysis using Python

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r"C:\Users\hp\Pictures\Screenshots")

# %%
df=pd.read_csv("Electric_Production.csv")

# %%
df
# Out:
#            DATE     Value
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df.index = df['DATE'].dt.to_period()

# %%
df = pd.read_csv("Electric_Production.csv", index_col="DATE")

# %%
df1=df.head(30)

# %%
df1
# Out:
#               Value
# DATE
# 01-01-1985  72.5052
# 02-01-1985  70.6720
# 03-01-1985  62.4502
# 04-01-1985  57.4714
# 05-01-1985  55.3151
# 06-01-1985  58.0904
# 07-01-1985  62.6202
# 08-01-1985  63.2485
# 09-01-1985  60.5846
# 10-01-1985  56.3154
# 11-01-1985  58.0005
# 12-01-1985  68.7145
# 01-01-1986  73.3057
# 02-01-1986  67.9869
# 03-01-1986  62.2221
# 04-01-1986  57.0329
# 05-01-1986  55.8137
# 06-01-1986  59.9005
# 07-01-1986  65.7655
# 08-01-1986  64.4816
# 09-01-1986  61.0005
# 10-01-1986  57.5322
# 11-01-1986  59.3417
# 12-01-1986  68.1354
# 01-01-1987  73.8152
# 02-01-1987  70.0620
# 03-01-1987  65.6100
# 04-01-1987  60.1586
# 05-01-1987  58.8734
# 06-01-1987  63.8918

# %%
df1.shape
# Out:
# (30, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397 entries, 01-01-1985 to 01-01-2018
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   397 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2+ KB

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 13,6
df1.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(df1, model='multiplicative', period=12)
decompose.plot()
plt.show()

# %%
df2_log=df1.copy()

# %%
df2_log["Value"]=np.log(df1)

# %%
df2_log["Value"]
# Out:
# DATE
# 01-01-1985    4.283658
# 02-01-1985    4.258049
# 03-01-1985    4.134369
# 04-01-1985    4.051287
# 05-01-1985    4.013046
# 06-01-1985    4.062000
# 07-01-1985    4.137088
# 08-01-1985    4.147071
# 09-01-1985    4.104041
# 10-01-1985    4.030968
# 11-01-1985    4.060452
# 12-01-1985    4.229960
# 01-01-1986    4.294638
# 02-01-1986    4.219315
# 03-01-1986    4.130710
# 04-01-1986    4.043628
# 05-01-1986    4.022019
# 06-01-1986    4.092685
# 07-01-1986    4.186095
# 08-01-1986    4.166380
# 09-01-1986    4.110882
# 10-01-1986    4.052345
# 11-01-1986    4.083312
# 12-01-1986    4.221497
# 01-01-1987    4.301565
# 02-01-1987    4.249381
# 03-01-1987    4.183728
# 04-01-1987    4.096984
# 05-01-1987    4.075389
# 06-01-1987    4.157191
# Name: Value, dtype: float64

# %%
df2_log.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(df1, model="additive", period=12)
decompose.plot()
plt.show()
